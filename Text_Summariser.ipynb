# %% [markdown]
# <a href="https://colab.research.google.com/github/SvshX/text-summariser/blob/master/Text_Summariser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import attention
from attention import AttentionLayer

# %%
import numpy as np
import pandas as pd 
import re
from bs4 import BeautifulSoup
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("Reviews.csv",nrows=100000)

# %%
data.drop_duplicates(subset=['Text'], inplace=True)   #dropping duplicates
data.dropna(axis=0, inplace=True)   #dropping na

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88421 entries, 0 to 99999
# Data columns (total 10 columns):
# Id                        88421 non-null int64
# ProductId                 88421 non-null object
# UserId                    88421 non-null object
# ProfileName               88421 non-null object
# HelpfulnessNumerator      88421 non-null int64
# HelpfulnessDenominator    88421 non-null int64
# Score                     88421 non-null int64
# Time                      88421 non-null int64
# Summary                   88421 non-null object
# Text                      88421 non-null object
# dtypes: int64(5), object(5)
# memory usage: 7.4+ MB

# %%
data['Text'][:10]
# Out:
# 0    I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1             Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2    This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3    If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4                                                               Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
# 5    I got a wild hair for taffy and ordered this five pound bag. The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc. My only complaint is there wa...
# 6    This saltwater taffy had great flavors and was very soft and chewy.  Each candy was individually wrapped well.  None of the candies were stuck together, which did happen in the expensive version, ...
# 7                                                               This taffy is so good.  It is very soft and chewy.  The flavors are amazing.  I would definitely recommend you buying it.  Very satisfying!!
# 8                                                                        Right now I'm mostly just sprouting this so my cats can eat the grass. They love it. I rotate it around with Wheatgrass and Rye too
# 9                                                                  This is a very healthy dog food. Good for their digestion. Also good for small puppies. My dog eats her required amount at every feeding.
# Name: Text, dtype: object

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
stop_words = set(stopwords.words('english')) 

def text_cleaner(text,num):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    newString = re.sub('[m]{2,}', 'mm', newString)
    if(num==0):
        tokens = [w for w in newString.split() if not w in stop_words]
    else:
        tokens=newString.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:                                                 #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

# %%
#call the function
cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t, 0))

# %%
cleaned_text[:5]
# Out:
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better',
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo',
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch',
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal',
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
#call the function
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(text_cleaner(t, 1))

# %%
cleaned_summary[:10]
# Out:
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy',
#  'nice taffy',
#  'great just as good as the expensive brands',
#  'wonderful tasty taffy',
#  'yay barley',
#  'healthy dog food']

# %%
data['cleaned_text'] = cleaned_text
data['cleaned_summary'] = cleaned_summary

# %%
data.replace('', np.nan, inplace=True)
data.dropna(axis=0, inplace=True)

# %%
import matplotlib.pyplot as plt

text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.show()

# %%
max_len_text = 30 
max_len_summary = 8

# %%
cleaned_text = np.array(data['cleaned_text'])
cleaned_summary = np.array(data['cleaned_summary'])

short_text = []
short_summary = []

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split()) <= max_summary_len and len(cleaned_text[i].split()) <= max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
df = pd.DataFrame({'text':short_text,'summary':short_summary})

# %%
df['summary'] = df['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(df['text']), np.array(df['summary']), test_size=0.1, random_state=0, shuffle=True)

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

# %%
thresh = 4

cnt = 0
tot_cnt = 0
freq = 0
tot_freq = 0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt = tot_cnt + 1
    tot_freq = tot_freq + value
    if(value < thresh):
        cnt = cnt + 1
        freq = freq + value
    
print("% of rare words in vocabulary:", (cnt/tot_cnt) * 100)
print("Total Coverage of rare words:", (freq/tot_freq) * 100)
# Out:
# % of rare words in vocabulary: 66.12339930151339
# Total Coverage of rare words: 2.953684513790566

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt - cnt)
x_tokenizer.fit_on_texts(list(x_tr))
#convert text sequences into integer sequences
x_tr = x_tokenizer.texts_to_sequences(x_tr) 
x_val = x_tokenizer.texts_to_sequences(x_val)
#padding zero upto maximum length
x_tr = pad_sequences(x_tr,  maxlen=max_len_text, padding='post') 
x_val = pad_sequences(x_val, maxlen=max_len_text, padding='post')
#size of vocabulary ( +1 for padding token)
x_voc = x_tokenizer.num_words + 1

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

# %%
thresh = 6

cnt = 0
tot_cnt = 0
freq = 0
tot_freq = 0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt = tot_cnt + 1
    tot_freq = tot_freq + value
    if(value < thresh):
        cnt = cnt + 1
        freq = freq + value
    
print("% of rare words in vocabulary:", (cnt/tot_cnt) * 100)
print("Total Coverage of rare words:", (freq/tot_freq) * 100)
# Out:
# % of rare words in vocabulary: 78.12740675541863
# Total Coverage of rare words: 5.3921899389571895

# %%
#preparing a tokenizer for summary on training data 
y_tokenizer = Tokenizer(num_words=tot_cnt - cnt)
y_tokenizer.fit_on_texts(list(y_tr))
#convert summary sequences into integer sequences
y_tr = y_tokenizer.texts_to_sequences(y_tr) 
y_val = y_tokenizer.texts_to_sequences(y_val) 
#padding zero upto maximum length
y_tr = pad_sequences(y_tr, maxlen=max_len_summary, padding='post')
y_val = pad_sequences(y_val, maxlen=max_len_summary, padding='post')
#size of vocabulary
y_voc = y_tokenizer.num_words + 1

# %%
y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# (42453, 42453)

# %%
ind = []
for i in range(len(y_tr)):
    cnt = 0
    for j in y_tr[i]:
        if j != 0:
            cnt = cnt + 1
    if(cnt == 2):
        ind.append(i)

y_tr = np.delete(y_tr, ind, axis=0)
x_tr = np.delete(x_tr, ind, axis=0)

# %%
ind = []
for i in range(len(y_val)):
    cnt = 0
    for j in y_val[i]:
        if j != 0:
            cnt = cnt + 1
    if(cnt == 2):
        ind.append(i)

y_val = np.delete(y_val, ind, axis=0)
x_val = np.delete(x_val, ind, axis=0)

# %%
from keras import backend as K 
K.clear_session() 
latent_dim = 500 
# Encoder 
encoder_inputs = Input(shape=(max_len_text,)) 
enc_emb = Embedding(x_voc, latent_dim, trainable=True)(encoder_inputs) 
#LSTM 1 
encoder_lstm1 = LSTM(latent_dim, return_sequences=True,return_state=True) 
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb) 
#LSTM 2 
encoder_lstm2 = LSTM(latent_dim, return_sequences=True,return_state=True) 
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1) 
#LSTM 3 
encoder_lstm3 = LSTM(latent_dim, return_state=True, return_sequences=True) 
encoder_outputs, state_h, state_c = encoder_lstm3(encoder_output2)

# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
dec_emb_layer = Embedding(y_voc, latent_dim, trainable=True) 
dec_emb = dec_emb_layer(decoder_inputs) 
#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True) 
decoder_outputs, decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c]) 
#Attention Layer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs]) 
# Concat attention output and decoder LSTM output 
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])
#Dense layer
decoder_dense = TimeDistributed(Dense(y_voc, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 
# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs) 
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 500)      4220000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 30, 500), (N 2002000     embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 30, 500), (N 2002000     lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 500)    994500      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 30, 500), (N 2002000     lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 500),  2002000     embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 500),  500500      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 1000)   0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 1989)   1990989     concat_layer[0][0]
# ==================================================================================================
# Total params: 15,713,989
# Trainable params: 15,713,989
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
history = model.fit([x_tr, y_tr[:, :-1]], y_tr.reshape(y_tr.shape[0], y_tr.shape[1], 1)[:, 1:], epochs=30, callbacks=[es], batch_size=128, validation_data=([x_val, y_val[:, :-1]], y_val.reshape(y_val.shape[0], y_val.shape[1], 1)[:, 1:]))
# Out:
# W0731 10:07:36.646786 140193167918976 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 41346 samples, validate on 4588 samples
# Epoch 1/30
# 41346/41346 [==============================] - 2164s 52ms/sample - loss: 2.6951 - val_loss: 2.4393
# Epoch 2/30
# 41346/41346 [==============================] - 2155s 52ms/sample - loss: 2.2981 - val_loss: 2.2323
# Epoch 3/30
# 41346/41346 [==============================] - 2159s 52ms/sample - loss: 2.1305 - val_loss: 2.1456
# Epoch 4/30
# 41346/41346 [==============================] - 2138s 52ms/sample - loss: 2.0066 - val_loss: 2.0768
# Epoch 5/30
# 41346/41346 [==============================] - 2146s 52ms/sample - loss: 1.9020 - val_loss: 2.0717
# Epoch 6/30
# 41346/41346 [==============================] - 2149s 52ms/sample - loss: 1.8068 - val_loss: 2.0106
# Epoch 7/30
# 41346/41346 [==============================] - 2152s 52ms/sample - loss: 1.7137 - val_loss: 2.0201
# Epoch 00007: early stopping

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend()
pyplot.show()

# %%
reverse_target_word_index = y_tokenizer.index_word 
reverse_source_word_index = x_tokenizer.index_word 
target_word_index = y_tokenizer.word_index

# %%
# encoder inference
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])
# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_len_text,latent_dim))
# Get the embeddings of the decoder sequence
dec_emb2 = dec_emb_layer(decoder_inputs)
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])
#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])
# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)
# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    # Chose the 'start' word as the first word of the target sequence
    target_seq[0, 0] = target_word_index['start']
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        if (sampled_token!='end'):
           decoded_sentence += ' '+sampled_token
        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'end' or len(decoded_sentence.split()) >= (max_len_summary-1)):
           stop_condition = True
        # Update the target sequence (of length 1).
           target_seq = np.zeros((1,1))
           target_seq[0, 0] = sampled_token_index
        # Update internal states
           e_h, e_c = h, c
    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
      if((i!=0 and i!=target_word_index['start']) and i!=target_word_index['end']):
        newString=newString+reverse_target_word_index[i]+' '
    return newString
def seq2text(input_seq):
    newString=''
    for i in input_seq:
      if(i!=0):
        newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(len(x_val)):
  print("Review:",seq2text(x_val[i]))
  print("Original summary:",seq2summary(y_val[i]))
  print("Predicted summary:",decode_sequence(x_val[i].reshape(1,max_len_text)))
  print("\n")
# Out:
# Review: great healthy chew old beagle rio loves taste sure beats arm
# Original summary: sostok yummy eostok
# Predicted summary:  to to to to to to to
#
#
# Review: thank goodness carbonated drink tasty without additives taste like cherry drinks slightly lighter flavoring although less half volume normal wonder things good comes small size least recycled
# Original summary: sostok it is tasty eostok
# Predicted summary:  to to to to to to to
#
#
# Review: extra bold coffee one favorites extra bold could compared bold coffee regular coffee brewer
# Original summary: sostok great coffee for keurig brewer eostok
# Predicted summary:  to to to to to to to
#
#
# Review: like flavored coffee taste like coffee may could taste coffee travel size brew smaller brew sizes bit better
# Original summary: too much caramel cream not enough coffee eostok
# Predicted summary:  to to to to to to to
#
#
# Review: slightly overpriced one kitty last month less pound bags recently purchased petsmart dollars pound bag
# Original summary: sostok great food eostok
# Predicted summary:  to to to to to to to
#
#
# Review: boss likes smarties saw giant smarties thought would funny handed small said call handing giant thought looked
# Original summary: sostok big hit at the office eostok
# Predicted summary:  to to to to to to to
#
#
# Review: grateful amazing mix used make best gluten free products break us gluten free individuals miss real mixes ones market dont trick like
# Original summary: sostok amazing eostok
# Predicted summary:  to to to to to to to
#
#
# Review: like even regular bisquick mix make pancakes taste closer scratch wheat flour pancakes members family tried yet used pizza crust biscuits
# Original summary: sostok just about perfect for pancakes eostok
# Predicted summary:  to to to to to to to
#
#
# Review: product wonderful like hot also good mixed ice milk blender love
# Original summary: sostok great eostok
# Predicted summary:  to to to to to to to
#
#
# Review: better tasting cheaper hr energy experience energy boost equal hr energy lasts long however prefer taste saves money
# Original summary: sostok better tasting than energy eostok
# Predicted summary:  to to to to to to to
#
#
# Review: product makes medicine oh easy big ol chocolate lab would sell soul greenies pill pocket
# Original summary: sostok idea for pet eostok
# Predicted summary:  to to to to to to to
#
#
# Review:
ostok
# Predicted summary:  to to to to to to to
#
#
# Review: excellent flavor properly done french roast smokey rich sufficiently strong though always think cups need coffee
# Original summary: sostok excellent eostok
# Predicted summary:  to to to to to to to
#
#
# Review: smooth taste strong without quality taste would expect way packaging makes wonder long sitting taste fresh normal ones buy donut shop going back brand
# Original summary: sostok tullys coffee average eostok
# Predicted summary:  to to to to to to to
#
#
# Review: easy order favorite coffee amazon love taste coffee ease brewing
# Original summary: amazon to the for senseo french vanilla eostok
# Predicted summary:  to to to to to to to
#
#
# Review: buy cereal case local store carry best raisin bran raisin eating opinion sweet like great flavor consistency
# Original summary: sostok the best cereal ever eostok
# Predicted summary:  to to to to to to to
#
#
# Review: favorite toy house extremely durable dogs get tired well worth money
# Original summary: sostok great toy eostok
# Predicted summary:  your your your your your your your
#
#
# Review: would like reorder excellent product currently unavailable happy first order hope come back soon
# Original summary: sostok excellent product eostok
# Predicted summary:  to to to to to to to
#
#
# Review: favorite chocolate since young loved came early wished cheaper though chocolate covering bit thicker
# Original summary: sostok best chocolate eostok
# Predicted summary:  to to to to to to to
#
#
# Review: excellent product tastes exactly way want huckleberry fix thing get
# Original summary: sostok delicious eostok
# Predicted summary:  to to to to to to to
#
#
# Review: tasting watermelon strawberry flavor pleasantly surprised good one tasted imagine carbonated juice natural overwhelming taste buds one real keeper light refreshing great flavor keeps us coming
# Original summary: sostok this flavor is actually pretty good eostok
# Predicted summary:  to to to to to to to
#
#
# Review: asin erin baker breakfast cookies oatmeal raisin ounce individually wrapped cookies love cookies breakfast snack keep feeling full hours give lots energy feel good eatting since healthy yummy
# Original summary: sostok love these cookies eostok
# Predicted summary:  to to to to to to to
#
#
# Review: rum cake awesome cannot get enough good want share anybody else
# Original summary: sostok powerful smell awesome taste eostok
# Predicted summary:  to to to to to to to
#
#
# Review: coffee outstanding thanks amazon arrived practically time one surprise however shipped via costco warehouse giant immensely pleased purchase thanks amazon
# Original summary: sostok rich flavorful kona three for three eostok
# Predicted summary:  to to to to to to to
#
#
# Review: smelled nice color light brown course grind french press weak drinkable opinion sure got bad one meant french press
# Original summary: sostok not for me eostok
# Predicted summary:  to to to to to to to
#
#
# Review: stash tea fan years price amazon grocery terrific yes drink chai every day throughout winter try regular decaf chai tablespoon two real cream perfect drink chilly days
# Original summary: sostok chai on cold winter night perfect eostok
# Predicted summary:  to to to to to to to
#
#
# Review: everything arrived good shape received wanted fast delivery would buy people
# Original summary: sostok instant noodles eostok
# Predicted summary:  to to to to to to to
#
#
# Review: delicious mild variety coffee overly strong like starbucks coffees order one repeatedly
# Original summary: sostok favorite starbucks flavor eostok
# Predicted summary:  to to to to to to to
#
#
# Review: purchased senseo work customers love flavor choices tasty cup coffee quickly hands coworkers also help cup forget bring vanilla bistro leading favorite flavors gotten good reviews around
# Original summary: sostok simple quick tasty eostok
# Predicted summary:  to to to to to to to
#
#
# Review: picky cats ordered case would touch sent mom several cats would touch either even dog would eat
# Original summary: sostok my cats will not eat it eostok
# Predicted summary:  to to to to to to to
#
#
# Review: pecans great cooking baking snacking shipping bit pricey delivery fast
# Original summary: sostok great pecans eostok
# Predicted summary:  to to to to to to to
#
#
# Review: love delicious reasonable substitute cat
# Original summary: sostok woof eostok
# Predicted summary:  to to to to to to to
#
#
# Review: long enjoyed combination fruit drink mixed sparkling water fruit drinks tend sweet syrupy taste sparkling water cuts adds zing carbonation well drink work well really enjoyed buy
# Original summary: sostok great tasting drink eostok
# Predicted summary:  to to to to to to to
#
#
# Review: great sandwich crackers wife uses pasta casserole also economical
# Original summary: sostok great snack food eostok
# Predicted summary:  to to to to to to to
#
#
# Review: ordered year ago repeatedly ordered since everyone shared loved much also gotten right amazon ordered also mix coffee feeling particularly top cream delicious
# Original summary: sostok totally hooked eostok
# Predicted summary:  to to to to to to to
#
#
# Review: gluten free foods eat lately actually really good definitely buying
# Original summary: sostok really really good eostok
# Predicted summary:  to to to to to to to
#
#
# Review: best brownie mix found bad amazon cannot keep stock maybe good thing since go way sugar fat whenever bake batch great take along trips long hikes
# Original summary: sostok gluten free and decadent eostok
# Predicted summary:  to to to to to to to
#
#
# Review: disappointed small size shocked brick like texture bar chewy name tastes good hard texture small size mind called amazon complaint received full refund thank
# Original summary: sostok not pleased eostok
# Predicted summary:  to to to to to to to
#
#
# Review: thought maybe dumped chewing mix spit mouth bad
# Original summary: sostok tastes like chewing eostok
# Predicted summary:  to to to to to to to
#
#
# Review: tasty however per nutrition info package one serving cookie calories half cookie fat half cookie grams eat whole thing calories grams fat
# Original summary: sostok tasty but eostok
# Predicted summary:  to to to to to to to
#
#
# Review: flavorful salt imagine cook nice thick steak sprinkle little salt cut side make meat pop mouth never experimented finishing salts great starting point
# Original summary: sostok my favorite eostok
# Predicted summary:  to to to to to to to
#
#
# Review: cats love flavor temptations treat time sit look husband get crumb left
# Original summary: sostok cat treats eostok
# Predicted summary:  my my my my my my my
#
#
# Review: hard find excited find online ordered bags enjoying ever since
# Original summary: sostok great eostok
# Predicted summary:  to to to to to to to
#
#
# Review: flavorings need add sugar add whatever flavor mood
# Original summary: sostok no need for sugar eostok
# Predicted summary:  to to to to to to to
#
#
# Review: great stuff dog teeth could treats others problem solved loves bit messy learned treat minimal dripping others beg save guy pleasure able reward potty call
# Original summary: sostok great treat eostok
# Predicted summary:  to to to to to to to
#
#
# Review: crackers perfect know subtle light flavour overpower whatever eating top whether guacamole hummus mustard cheese
# Original summary: sostok yum eostok
# Predicted summary:  to to to to to to to
#
#
# Review: favorite tea regular green tea tastes little bitter addition brown rice gives tea nice smokey flavor winter drink least two cups day cannot get enough
# Original summary: sostok yummy eostok
# Predicted summary:  to to to to to to to
#
#
# Review: sure pepperoni slices would taste like pleased purchase unlike review foul smell upon opening packages taste right packaging great definitely ordering
# Original summary: sostok pleased eostok
# Predicted summary:  to to to to to to to
#
#
# Review: add labs meals morning joints expense products caused allergy problems problems last year
# Original summary: sostok support of eostok
# Predicted summary:  to to to to to to to
#
#
# Review: best olive oil well worth price hard find happy find amazon regular customer great value outstanding product
# Original summary: sostok olive oil eostok
# Predicted summary:  to to to to to to to
#
#
# Review: delicious oz bags distinct flavor smaller bags cannot keep house long husband gobbles right away
# Original summary: sostok my husband is addicted to these eostok
# Predicted summary:  to to to to to to to
#
#
# Review: boxes oz plus shipping stores
# Original summary: sostok are you serious with this price eostok
# Predicted summary:  to to to to to to to
#
#
# Review: pop chips really good tasty healthy potato based horrible gluten free dang little starch eating regimen tasty made sick
# Original summary: really good but no more for me eostok
# Predicted summary:  to to to to to to to
#
#
# Review: husband always cup big easy bold every morning quality consistent past several years ordered like dark roast without bitterness sometimes found dark roasts coffee
# Original summary: of the best dark roast coffees available eostok
# Predicted summary:  to to to to to to to
#
#
# Review: great tasting jell without sweet natural tasting low calories well sugar content
# Original summary: sostok without being too sweet eostok
# Predicted summary:  to to to to to to to
#
#
# Review: large boxes cereal great price husband eating cereal box per box loving taste lasting effect lunch happy deal
# Original summary: sostok raisin bran cereal eostok
# Predicted summary:  to to to to to to to
#
#
# Review:
ostok
# Predicted summary:  to to to to to to to
#
#
# Review: like remember kid mom used uncle used little bigger version bonsai good item
# Original summary: sostok like remember eostok
# Predicted summary:  to to to to to to to
#
#
# Review: purchased green tea vendors quality much better course paid quite bit well goes prove get pay bag lot stems debris would recommend pay higher price get better quality tea
# Original summary: sostok not such eostok
# Predicted summary:  good good good good good good good
#
#
# Review: good like salt vinegar potato chips substantial delicious almond gives nice hint sweetness vinegar eaten one sitting
# Original summary: sostok fan eostok
# Predicted summary:  to to to to to to to
#
#
# Review: like cheese doodles love natural cheesy love portion control packages
# Original summary: sostok tasty wholesome snack eostok
# Predicted summary:  to to to to to to to
#
#
# Review: nephew ca turned packed take home used glad order line love everything reviews salt make low salt version try great burgers steaks chicken
# Original summary: sostok love this stuff eostok
# Predicted summary:  to to to to to to to
#
#
# Review: purchased warehouse deal lack aroma opening package know sitting long lack flavor character normal product two stars still drinkable boring
# Original summary: sostok disappointing eostok
# Predicted summary:  to to to to to to to
#
#
# Review: excellent product would buy better expecting complain
# Original summary: sostok excellent product eostok
# Predicted summary:  to to to to to to to
#
#
# Review: cat making worse constant scratching changed kitty food within two weeks gone ate seen since healthiest recommend without reservation
# Original summary: sostok healthy kitty eostok
# Predicted summary:  to to to to to to to
#
#
# Review: grandson love flavor coffee prefer darker brands hit would purchase coffee highly recommend
# Original summary: excellent flavor if you like dark coffee eostok
# Predicted summary:  to to to to to to to
#
#
# Review: searching great tasting crispy snack contains corn wheat gluten finally found soy crisps satisfy wishes
# Original summary: sostok delicious eostok
# Predicted summary:  to to to to to to to
#
#
# Review: product comes fast enough allow mom make cakes favorable price little higher thought
# Original summary: sostok good eostok
# Predicted summary:  to to to to to to to
#
#
# Review: good folgers version significantly better far amazon carry good price though like free shipping certain last huge supply hand makes hard make coffee way though sooo easy
# Original summary: sostok good but folgers version is better eostok
# Predicted summary:  to to to to to to to
#
#
# Review: bottle small package big drank half bottle way gym hype good way nt feel tired bad feeling nothing love product continue buying
# Original summary: sostok this little bottle is it eostok
# Predicted summary:  to to to to to to to
#
#
# Review: daughter loved cotton candy hard find stores glad found online
# Original summary: sostok my daughter loved this eostok
# Predicted summary:  to to to to to to to
#
#
# Review: taste great fat content suggests might well use
# Original summary: sostok great tasting but way too eostok
# Predicted summary:  to to to to to to to
#
#
# Review: delicious crackers ship well many end broken process
# Original summary: sostok delicious but do not ship well eostok
# Predicted summary:  as as as as as as as
#
#
# Review: absolutely love zico taste superb drink daily basis refreshing makes feel hydrated workout loved cartons new bottle amazing close carry everywhere recommended friends hooked ordered another case thank zico
# Original summary: sostok better than ever eostok
# Predicted summary:  to to to to to to to
#
#
# Review: small swedish fish arrived good condition fresh yummy recommend occasion yummy ice cream
# Original summary: sostok always delish eostok
# Predicted summary:  to to to to to to to
#
#
# Review: particularly care flavors thought would try new chocolate flavor really good continue order could find anywhere except amazon
# Original summary: sostok zico coconut water chocolate eostok
# Predicted summary:  to to to to to to to
#
#
# Review: good sweet taste kind chinese sweet bbq sauce high protein
# Original summary: sostok sweet eostok
# Predicted summary:  to to to to to to to
#
#
# Review: order dog time last order purchased snack smashed almost powder form instead like little nuggets usually happy
# Original summary: sostok disappointed eostok
# Predicted summary:  to to to to to to to
#
#
# Review: really nice whisky sweet malt floral citrus salt honey character velvety smooth mouth feel wonderful oily short finish excellent high quality cheeses italian meats dinner
# Original summary: sostok wonderful eostok
# Predicted summary:  to to to to to to to
#
#
# Review: excited receive thought would cut calories like taste baked banana bread threw going try brownies add little bit maybe add enough thought taste though still use try
# Original summary: sostok did not really like it eostok
# Predicted summary:  to to to to to to to
#
#
# Review: passion kitchen love people life preparing best compromise quality mustard powder modified cover satisfy tastes kitchen would complete without
# Original summary: sostok serious kitchen must have eostok
# Predicted summary:  to to to to to to to
#
#
# Review: frosted mini wheats mixed cinnamon life nice healthy taste like
# Original summary: sostok love it eostok
# Predicted summary:  to to to to to to to
#
#
# Review: tastes great got fast ordered air popper sister loved much
# Original summary: sostok popcorn eostok
# Predicted summary:  to to to to to to to
#
#
# Review: delicious crunchy substantial even puppy whenever nibble best snack could get hands could help hey cares organic apple
# Original summary: sostok very healthy satisfying snack substitute eostok
# Predicted summary:  to to to to to to to
#
#
# Review: lot line research finally ordering chest christmas present daughter law wanted right thrilled opened mailing container saw fine wood high quality wonderful selection teas classy
# Original summary: sostok just right eostok
# Predicted summary:  to to to to to to to
#
#
# Review: dogs digging flavor merrick dry dog food products fast shipping seller made purchase even better thank
# Original summary: sostok tasty eostok
# Predicted summary:  to to to to to to to
#
#
# Review: obtained sample order really enhanced effects causing order immediately highly recommend product
# Original summary: sostok amazing eostok
# Predicted summary:  to to to to to to to
#
#
# Review: bought years always enjoys much knows word dingo means dingo treat time
# Original summary: sostok old by that still loves eostok
# Predicted summary:  to to to to to to to
#
#
# Review: little pricey absolutely best whole wheat spaghetti ever eaten order enjoy
# Original summary: sostok yum yum eostok
# Predicted summary:  to to to to to to to
#
#
# Review: first things first actually work tried tons different foods tasted lot better tried already must definitely great experience
# Original summary: sostok these berries are awesome eostok
# Predicted summary:  to to to to to to to
#
#
# Review: rec yesterday shipping super speedy candy extremely fresh order without hesitation
# Original summary: sostok amazing eostok
# Predicted summary:  to to to to to to to
#
#
# Review: made butter chicken peas paste great dish use half packet give flavor aside adding little chili onions need anything else
# Original summary: sostok excellent curry paste for everything eostok
# Predicted summary:  to to to to to to to
#
#
# Review: rich smooth unlike bold brands bitter grew coffee supreme really leads pack
# Original summary: sostok best coffee in the eostok
# Predicted summary:  to to to to to to to
#
#
# Review: dogs love treats beg sometimes sprinkle treats top food special treat also amazon ships fast get quickly
# Original summary: sostok dog treats eostok
# Predicted summary:  to to to to to to to
#
#
# Review: ordered serve tea speaking roses hit enough try
# Original summary: sostok rose hip tea eostok
# Predicted summary:  to to to to to to to
#
#
# Review: love coffee smooth taste lovely kona blend best freeze dried instant would purchase
# Original summary: sostok kona at its best eostok
# Predicted summary:  to to to to to to to
#
#
# Review: glad access hard find product local stores bit pricy though
# Original summary: sostok coffee creamer eostok
# Predicted summary:  to to to to to to to
#
#
# Review: salsas hot palate terrific salsa raspberries add right sweetness hot salsa buy
# Original summary: sostok good taste eostok
# Predicted summary:  to to to to to to to
#
#
# Review: disappointed flavor lack stash usually dependable products real
# Original summary: sostok not great eostok
# Predicted summary:  to to to to to to to
#
#
# Review: cannot imagine reviewer thinking perfect healthy treats dogs breeds dogs love make absolutely mess
# Original summary: sostok perfect treats for large dogs eostok
# Predicted summary:  to to to to to to to
#
#
# Review: heard chips thought would good alternative regular chips could eat though taste good personally grandmother loved though gave rest
# Original summary: sostok did not like the taste eostok
# Predicted summary:  to to to to to to to
#
#
# Review: good like darker bitter decent cup joe buy guests mine also commented liked flavor crowd pleaser nothing really exceptional could call
# Original summary: sostok really decent eostok
# Predicted summary:  to to to to to to to
#
#
# Review: bought one also one comes stand nice liked idea put either gum candy adjust much comes almost months works perfect large gumball bank going buy couple christmas gifts
# Original summary: sostok really nice and candy eostok
# Predicted summary:  to to to to to to to
#
#
# Review: exactly described nice try several different flavors blueberry good good change
# Original summary: sostok great eostok
# Predicted summary:  to to to to to to to
#
#
# Review:
ostok
# Predicted summary:  to to to to to to to
#
#
# Review: dog loves stix takes runs fast back bed enjoy
# Original summary: sostok dingo eostok
# Predicted summary:  to to to to to to to
#
#
# Review: lot reviews say coffee smooth wife disagree think bitter order beans open trying jeremiah products
# Original summary: sostok okay coffee eostok
# Predicted summary:  to to to to to to to
#
#
# Review: please dont buy dog food corn main ingredient cant digest pass spend little glad less dog waste better fur happy full dog little internet research bag cost worth
# Original summary: sostok better for your loved one eostok
# Predicted summary:  to to to to to to to
#
#
# Review: earl grey tea zing different brand husband likes zing sure worth trying want black tea real strong
# Original summary: sostok has eostok
# Predicted summary:  to to to to to to to
#
#
# Review: uses agave abundant like delivered several times year keeps well great sweetener
# Original summary: sostok madhava organic agave eostok
# Predicted summary:  to to to to to to to
#
#
# Review: heard drink friend try one traveling loved sat plane enjoying thinking bought another one
# Original summary: sostok awesome tasting eostok
# Predicted summary:  to to to to to to to
#
#
# Review: love crackers cheesy good way easy eat best way found eat get small bowl raspberry applesauce start dipping delicious
# Original summary: sostok like these little too much eostok
# Predicted summary:  to to to to to to to
#
#
# Review: one ingredient oatmeal sugar salt preservatives natural flavors food dyes none whole grain goodness cooks minutes love oatmeal
# Original summary: sostok whole grain oats eostok
# Predicted summary:  to to to to to to to
#
#
# Review: delicious healthy calories decadent rich taste usually buy big bag perfect amount snack chocolate boost
# Original summary: sostok the perfect snack eostok
# Predicted summary:  to to to to to to to
#
#
# Review: palm island premium red sea salt really great look great taste texture got barbeque arsenal ready summer try roasts
# Original summary: sostok beautiful and tasty sea salt eostok
# Predicted summary:  to to to to to to to
#
#
# Review: love yakisoba noodles favorite instant noodles time least favorite flavor ones though gave stars teriyaki best teriyaki beef mediocre taste good
# Original summary: sostok tastes better than beef eostok
# Predicted summary:  to to to to to to to
#
#
# Review: product exceeded expectations come family sensitive diets one passed test also super great nutritional content
# Original summary: sostok awesome product eostok
# Predicted summary:  to to to to to to to
#
#
# Review: much say looking citric acid cannot beat price use part homemade dishwasher detergent keep dishes getting
# Original summary: sostok perfect for my needs great price eostok
# Predicted summary:  to to to to to to to
#
#
# Review: gave gift great cannot go wrong amazon make sure leave warmth day chocolate might melt home deliver made
# Original summary: sostok cookies eostok
# Predicted summary:  to to to to to to to
#
#
# Review: liked tubs months realized contain fish oil gelatin put products food beware going review gerber products carefully totally dissapointed gerber
# Original summary: sostok not has fish oil and eostok
# Predicted summary:  to to to to to to to
#
#
# Review: clearly distinct maynards wine gums roll pack perfectly acceptable wine gums little sweeter little less chewy still definite tartness flavoring satisfying missing gummis relatives
# Original summary: sostok chewy and not too sweet eostok
# Predicted summary:  to to to to to to to
#
#
# Review: best buy found dog goes crazy happy give treat hope get back stock future
# Original summary: sostok smokehouse count ears eostok
# Predicted summary:  to to to to to to to
#
#
# Review: hour shots right amount energy need lunch feel lazy meal would like take rest take hour shot got power work rest day
# Original summary: sostok hour shot eostok
# Predicted summary:  to to to to to to to
#
#
# Review: recently received variety packs popchips delivered work everyone loves tried one flavor delicious next flavor excellent next flavor oh goodness even better gets better better best snack recent memory
# Original summary: sostok popchips eostok
# Predicted summary:  the the the the the the the
#
#
# Review: dog loves learned word greenie good treats like favored treat use one day accepted loves good teeth better teeth
# Original summary: sostok greenies are treats eostok
# Predicted summary:  to to to to to to to
#
#
# Review: hard chew like bought lb packet nobody family interested money
# Original summary: sostok not happy eostok
# Predicted summary:  to to to to to to to
#
#
# Review: great deal much cheaper pet store dog loves helps breath smell better used terrible gotten better eating wish lasted longer chew one minutes
# Original summary: sostok great eostok
# Predicted summary:  to to to to to to to
#
#
# Review: sure really make lose weight give energy boost without jittery feeling
# Original summary: sostok great product eostok
# Predicted summary:  to to to to to to to
#
#
# Review: great use cooking baking putting tea coffee like using white powder texture good fact counts makes easy count calories cheating much spoonful
# Original summary: sostok for tea and coffee eostok
# Predicted summary:  to to to to to to to
#
#
# Review: lot hiking backpacking able find product members family eat taste like cherry pie loaded sugar like healthy bars
# Original summary: sostok these are very tasty eostok
# Predicted summary:  to to to to to to to
#
#
# Review: love tea decaf green flavorful cannot find anymore area love quick delivery amazon
# Original summary: sostok green tea eostok
# Predicted summary:  to to to to to to to
#
#
# Review: bought candy mother italian gave one box mother sent box donated box italian family reunion loved individually boxed candy children used individual boxes play kitchen set loved candy packaging
# Original summary: good to the taste pleasant to the eostok
# Predicted summary:  the the the the the the the
#
#
# Review: three boys love sprout foods tried one last two months turkey herb roasted vegetables eat someone else also mentioned herb smell strong
# Original summary: sostok love sprout but not this one eostok
# Predicted summary:  to to to to to to to
#
#
# Review: fits kuerig pike place starbucks favorite say happy arrived fast complete good packaging
# Original summary: sostok it is from eostok
# Predicted summary:  to to to to to to to
#
#
# Review: newman pretzels far best ever get pretzel sticks local store always preferred rods much better snyder fact ingredients list short sweet gravy
# Original summary: sostok best pretzels ever eostok
# Predicted summary:  the the the the the the the
#
#
# Review: best cup hot cocoa market bar none would without house especially winter months coming
# Original summary: sostok great eostok
# Predicted summary:  to to to to to to to
#
#
# Review: picked cheap pound pound tasted great also want fruit product met expectations tastes really good
# Original summary: sostok cheap and tastes great eostok
# Predicted summary:  to to to to to to to
#
#
# Review: kids try offer healthy options much possible happy find product local target kids really liked flavor keep hand purse car pinch offer organic snack plan checking flavors well
# Original summary: an organic option that my kids loved eostok
# Predicted summary:  to to to to to to to
#
#
# Review: stumbled upon great coffee might say morning blend family friends think best yet
# Original summary: sostok san francisco bay morning blend cups eostok
# Predicted summary:  to to to to to to to
#
#
# Review: dog thoroughly enjoyed calming chews moments finishing first one high fit truck drove noticeably treats seems way keep dog busy happy expect changes
# Original summary: sostok dog loved it but no eostok
# Predicted summary:  to to to to to to to
#
#
# Review: super fast shipping nice presentation packaged well laws loved highly recommend enjoy
# Original summary: sostok great service eostok
# Predicted summary:  to to to to to to to
#
#
# Review: taste awesome esp salt pepper one love really healthy packaging really good
# Original summary: sostok amazing eostok
# Predicted summary:  to to to to to to to
#
#
# Review: great maynards still really good right cheaper expected good quality
# Original summary: sostok great value eostok
# Predicted summary:  to to to to to to to
